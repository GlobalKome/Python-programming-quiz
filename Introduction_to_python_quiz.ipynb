# %% [markdown]
# <a href="https://colab.research.google.com/github/GlobalKome/Python-programming-quiz/blob/main/Introduction_to_python_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
fao_data = pd.read_csv(url, encoding = "latin-1")
fao_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
fao_data.shape
# Out:
# (60943, 12)

# %%
len(fao_data['Area'].unique())
# Out:
# 49

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age', 'Nationality', 'Overall']
pd.DataFrame(lst, columns = col, index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
fao_data.groupby('Area')['Y2017', 'Area'].sum()
# Out:
# <ipython-input-35-1371e8cba8e9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fao_data.groupby('Area')['Y2017', 'Area'].sum()
# <ipython-input-35-1371e8cba8e9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fao_data.groupby('Area')['Y2017', 'Area'].sum()
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
array  = [[94, 89, 63],
           [93, 92, 48],
           [92, 94, 56]]
array[:2, 1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fb36e6c43fbb> in <cell line: 4>()
#       2            [93, 92, 48],
#       3            [92, 94, 56]]
# ----> 4 array[:2, 1:]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
fao_data.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
mean_fao_2017 = fao_data['Y2017'].mean().round(2)
std_fao_2017 = fao_data['Y2017'].std().round(2)

mean_fao_2017, std_fao_2017
# Out:
# (140.92, 1671.86)

# %%
fao_data.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
np.corrcoef(fao_data['Element Code'])
# Out:
# 1.0

# %%
fao_data.groupby('Item')['Y2015','Y2018'].agg(['sum', 'mean'])
# Out:
# <ipython-input-61-a7da187880f7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fao_data.groupby('Item')['Y2015','Y2018'].agg(['sum', 'mean'])
#                          Y2015                  Y2018
#                            sum        mean        sum        mean
# Item
# Alcohol, Non-Food      2180.00    8.044280    2293.00    8.399267
# Alcoholic Beverages   98783.72  176.715063   97847.27  174.415811
# Animal Products       11811.73   87.494296   11578.61   85.767481
# Animal fats          200675.72  317.023254  269648.27  423.975267
# Apples and products   10559.15   20.663699    9640.51   18.977382
# ...                        ...         ...        ...         ...
# Vegetables, Other    158104.08  275.923351  163987.21  284.700017
# Vegetal Products     107064.17  793.067926  107775.39  798.336222
# Wheat and products   234710.51  362.207577  242645.19  375.031206
# ...

# %%
fao_missing = fao_data['Y2014'].isnull().sum()
fao_percent_missing = round(fao_data['Y2014'].isnull().mean()*100, 3)

fao_missing, fao_percent_missing
# Out:
# (1589, 2.607)

# %%
fao_data.groupby('Element')['Stock Variation'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-898dc3cd0406> in <cell line: 1>()
# ----> 1 fao_data.groupby('Element')['Stock Variation'].sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
#     249             subset = self.obj[key]
#     250             ndim = subset.ndim
#
# KeyError: 'Column not found: Stock Variation'
